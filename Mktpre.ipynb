# %%
import pandas as pd

# %%
mkt_data = pd.read_csv('dataset.csv')

# %%
mkt_data
# Out:
#                                pork                  sandwich bags  \
# 0                           shampoo                      hand soap
# 1                              pork                           soap
# 2                             juice                     lunch meat
# 3                             pasta                      tortillas
# 4                      toilet paper                           eggs
# 5                      paper towels                      tortillas
# 6                             juice                   paper towels
# 7                           poultry                     coffee/tea
# 8                        coffee/tea                   toilet paper
# 9                         ice cream                           soda
# 10                        tortillas                           pork
# 11                           fruits                   all- purpose
# 12                     dinner rolls               individual meals
# ...

# %%
mkt_data.describe()
# Out:
#                pork  sandwich bags   lunch meat  all- purpose        flour  \
# count          1498           1498         1498          1498         1498
# unique           38             38           38            38           39
# top      vegetables     vegetables   vegetables    vegetables   vegetables
# freq            108             98           95           140          113
#
#                soda       butter   vegetables         beef  aluminum foil  \
# count          1447         1410         1355         1299           1240
# unique           39           39           39           39             39
# top      vegetables   vegetables   vegetables   vegetables     vegetables
# freq             97           95          102           89             98
#
#         all- purpose.1  dinner rolls      shampoo  all- purpose.2
# count             1202          1155         1102            1043
# unique              39            39           39              39
# ...

# %%
mkt_data_pro = mkt_data.dropna(axis=0)

# %%
mkt_data_pro
# Out:
#                                pork                  sandwich bags  \
# 0                           shampoo                      hand soap
# 1                              pork                           soap
# 3                             pasta                      tortillas
# 4                      toilet paper                           eggs
# 5                      paper towels                      tortillas
# 8                        coffee/tea                   toilet paper
# 9                         ice cream                           soda
# 10                        tortillas                           pork
# 11                           fruits                   all- purpose
# 13                        ice cream                        cereals
# 14                    sandwich bags                          flour
# 17                laundry detergent                     coffee/tea
# 18     dishwashing liquid/detergent                         yogurt
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(mkt_data, mkt_data_pro, label='linear')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-4a720e6e6e59> in <module>
# ----> 1 plt.plot(mkt_data, mkt_data_pro, label='linear')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...
